# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)

# %%
df = pd.read_csv('Reviews.csv')
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
df.describe()
# Out:
#                   Id  HelpfulnessNumerator  HelpfulnessDenominator  \
# count  568454.000000         568454.000000            568454.00000
# mean   284227.500000              1.743817                 2.22881
# std    164098.679298              7.636513                 8.28974
# min         1.000000              0.000000                 0.00000
# 25%    142114.250000              0.000000                 0.00000
# 50%    284227.500000              0.000000                 1.00000
# 75%    426340.750000              2.000000                 2.00000
# max    568454.000000            866.000000               923.00000
#
#                Score          Time
# count  568454.000000  5.684540e+05
# mean        4.183199  1.296257e+09
# std         1.310436  4.804331e+07
# min         1.000000  9.393408e+08
# 25%         4.000000  1.271290e+09
# 50%         5.000000  1.311120e+09
# 75%         5.000000  1.332720e+09
# max         5.000000  1.351210e+09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568454 entries, 0 to 568453
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Id                      568454 non-null  int64
#  1   ProductId               568454 non-null  object
#  2   UserId                  568454 non-null  object
#  3   ProfileName             568438 non-null  object
#  4   HelpfulnessNumerator    568454 non-null  int64
#  5   HelpfulnessDenominator  568454 non-null  int64
#  6   Score                   568454 non-null  int64
#  7   Time                    568454 non-null  int64
#  8   Summary                 568427 non-null  object
#  9   Text                    568454 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 43.4+ MB

# %%
df.shape
# Out:
# (568454, 10)

# %%
df.count() #To see if there are any columns have missing values
# Out:
# Id                        568454
# ProductId                 568454
# UserId                    568454
# ProfileName               568438
# HelpfulnessNumerator      568454
# HelpfulnessDenominator    568454
# Score                     568454
# Time                      568454
# Summary                   568427
# Text                      568454
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Id                         0
# ProductId                  0
# UserId                     0
# ProfileName               16
# HelpfulnessNumerator       0
# HelpfulnessDenominator     0
# Score                      0
# Time                       0
# Summary                   27
# Text                       0
# dtype: int64

# %% [markdown]
# ## We see that Summary and PofileName have some null or missing values. Since summary might tell us about the overall important aspect about the review it plays a crucial role in sentiment analysis. This can not be replaced by any other values hence better to concatenate them with the Text attribute instead of dropping them on the whole.

# %%
df[df["Summary"].isnull()] #Prints all those rows whose summary is NaN
# Out:
#             Id   ProductId          UserId                     ProfileName  \
# 33958    33959  B00412W76S  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 40548    40549  B00020HHRW  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 101106  101107  B0014B0HWK  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 102979  102980  B000FVDWU4  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 117515  117516  B0016B7Z32  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 155712  155713  B0009VO58S  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 178290  178291  B00073IVAQ  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 198474  198475  B000FVBYCW  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 212691  212692  B00020HHAO  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 237565  237566  B000ELGPAO  A15AMT9T9A1309                     Film-Friend
# 293906  293907  B00020HHM2  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 299495  299496  B00142BX68  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 300961  300962  B000VJYTZM  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 333556  333557  B00188S3PM  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 352043  352044  B000M0F58U  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 357215  357216  B0006I5M2M  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 357814  357815  B001GCTTRQ  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 360782  360783  B00020HHHC  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 379473  379474  B007RLRCLK  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 380558  380559  B00014DXCC  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 381313  381314  B00020HHK4  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 386283  386284  B00073JVFU  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 392529  392530  B001H9XOEW  A22R17YPXEULEZ                        Liz Wong
# 484367  484368  B00020HHGS  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 486640  486641  B0014AUJII  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 503260  503261  B00020HHE0  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 530716  530717  B0014ATRV8  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 33958                      1                      24      2  1173312000
# 40548                      1                      24      2  1173312000
# 101106                     1                      24      2  1173312000
# 102979                     1                      24      2  1173312000
# 117515                     1                      24      2  1173312000
# 155712                     1                      24      2  1173312000
# 178290                     1                      24      2  1173312000
# 198474                     1                      24      2  1173312000
# 212691                     1                      24      2  1173312000
# 237565                     1                       1      3  1328572800
# 293906                     1                      24      2  1173312000
# 299495                     1                      24      2  1173312000
# 300961                     1                      24      2  1173312000
# 333556                     1                      24      2  1173312000
# 352043                     1                      24      2  1173312000
# 357215                     1                      24      2  1173312000
# 357814                     1                      24      2  1173312000
# 360782                     1                      24      2  1173312000
# 379473                     1                      24      2  1173312000
# 380558                     1                      24      2  1173312000
# 381313                     1                      24      2  1173312000
# 386283                     1                      24      2  1173312000
# 392529                     0                       0      3  1334534400
# 484367                     1                      24      2  1173312000
# 486640                     1                      24      2  1173312000
# 503260                     1                      24      2  1173312000
# 530716                     1                      24      2  1173312000
#
#        Summary                                               Text
# 33958      NaN  I only used two maybe three tea bags and got p...
# 40548      NaN  I only used two maybe three tea bags and got p...
# 101106     NaN  I only used two maybe three tea bags and got p...
# 102979     NaN  I only used two maybe three tea bags and got p...
# 117515     NaN  I only used two maybe three tea bags and got p...
# 155712     NaN  I only used two maybe three tea bags and got p...
# 178290     NaN  I only used two maybe three tea bags and got p...
# 198474     NaN  I only used two maybe three tea bags and got p...
# 212691     NaN  I only used two maybe three tea bags and got p...
# 237565     NaN  This is a cool system only problem is that the...
# 293906     NaN  I only used two maybe three tea bags and got p...
# 299495     NaN  I only used two maybe three tea bags and got p...
# 300961     NaN  I only used two maybe three tea bags and got p...
# 333556     NaN  I only used two maybe three tea bags and got p...
# 352043     NaN  I only used two maybe three tea bags and got p...
# 357215     NaN  I only used two maybe three tea bags and got p...
# 357814     NaN  I only used two maybe three tea bags and got p...
# 360782     NaN  I only used two maybe three tea bags and got p...
# 379473     NaN  I only used two maybe three tea bags and got p...
# 380558     NaN  I only used two maybe three tea bags and got p...
# 381313     NaN  I only used two maybe three tea bags and got p...
# 386283     NaN  I only used two maybe three tea bags and got p...
# 392529     NaN  I like the product and tried it before I pucha...
# 484367     NaN  I only used two maybe three tea bags and got p...
# 486640     NaN  I only used two maybe three tea bags and got p...
# 503260     NaN  I only used two maybe three tea bags and got p...
# 530716     NaN  I only used two maybe three tea bags and got p...

# %%
# df["Combined"] = df[~df["Summary"].isnull()]["Summary"] + df["Text"]

# %%
df_treated = df.copy()
df_treated
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                          1                       1      5  1303862400
# 1                          0                       0      1  1346976000
# 2                          1                       1      4  1219017600
# 3                          3                       3      2  1307923200
# 4                          0                       0      5  1350777600
# ...                      ...                     ...    ...         ...
# 568449                     0                       0      5  1299628800
# 568450                     0                       0      2  1331251200
# 568451                     2                       2      5  1329782400
# 568452                     1                       1      5  1331596800
# 568453                     0                       0      5  1338422400
#
#                                    Summary  \
# 0                    Good Quality Dog Food
# 1                        Not as Advertised
# 2                    "Delight" says it all
# 3                           Cough Medicine
# 4                              Great taffy
# ...                                    ...
# 568449                 Will not do without
# 568450                        disappointed
# 568451            Perfect for our maltipoo
# 568452  Favorite Training and reward treat
# 568453                         Great Honey
#
#                                                      Text
# 0       I have bought several of the Vitality canned d...
# 1       Product arrived labeled as Jumbo Salted Peanut...
# 2       This is a confection that has been around a fe...
# 3       If you are looking for the secret ingredient i...
# 4       Great taffy at a great price.  There was a wid...
# ...                                                   ...
# 568449  Great for sesame chicken..this is a good if no...
# 568450  I'm disappointed with the flavor. The chocolat...
# 568451  These stars are small, so you can give 10-15 o...
# 568452  These are the BEST treats for training and rew...
# 568453  I am very satisfied ,product is as advertised,...
#
# [568454 rows x 10 columns]

# %%
df_treated.Summary = df_treated.Summary.fillna('')
df_treated["ReviewText"] = df_treated["Summary"] + " & " + df_treated["Text"]
#everything before the first occurence of an "&" is part of the
#summary and the later is the actual reveiw all combined into one column called ReviewText

# %%
df_treated[df_treated["Summary"]==""]
# Out:
#             Id   ProductId          UserId                     ProfileName  \
# 33958    33959  B00412W76S  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 40548    40549  B00020HHRW  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 101106  101107  B0014B0HWK  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 102979  102980  B000FVDWU4  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 117515  117516  B0016B7Z32  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 155712  155713  B0009VO58S  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 178290  178291  B00073IVAQ  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 198474  198475  B000FVBYCW  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 212691  212692  B00020HHAO  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 237565  237566  B000ELGPAO  A15AMT9T9A1309                     Film-Friend
# 293906  293907  B00020HHM2  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 299495  299496  B00142BX68  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 300961  300962  B000VJYTZM  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 333556  333557  B00188S3PM  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 352043  352044  B000M0F58U  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 357215  357216  B0006I5M2M  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 357814  357815  B001GCTTRQ  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 360782  360783  B00020HHHC  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 379473  379474  B007RLRCLK  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 380558  380559  B00014DXCC  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 381313  381314  B00020HHK4  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 386283  386284  B00073JVFU  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 392529  392530  B001H9XOEW  A22R17YPXEULEZ                        Liz Wong
# 484367  484368  B00020HHGS  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 486640  486641  B0014AUJII  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 503260  503261  B00020HHE0  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 530716  530717  B0014ATRV8  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 33958                      1                      24      2  1173312000
# 40548                      1                      24      2  1173312000
# 101106                     1                      24      2  1173312000
# 102979                     1                      24      2  1173312000
# 117515                     1                      24      2  1173312000
# 155712                     1                      24      2  1173312000
# 178290                     1                      24      2  1173312000
# 198474                     1                      24      2  1173312000
# 212691                     1                      24      2  1173312000
# 237565                     1                       1      3  1328572800
# 293906                     1                      24      2  1173312000
# 299495                     1                      24      2  1173312000
# 300961                     1                      24      2  1173312000
# 333556                     1                      24      2  1173312000
# 352043                     1                      24      2  1173312000
# 357215                     1                      24      2  1173312000
# 357814                     1                      24      2  1173312000
# 360782                     1                      24      2  1173312000
# 379473                     1                      24      2  1173312000
# 380558                     1                      24      2  1173312000
# 381313                     1                      24      2  1173312000
# 386283                     1                      24      2  1173312000
# 392529                     0                       0      3  1334534400
# 484367                     1                      24      2  1173312000
# 486640                     1                      24      2  1173312000
# 503260                     1                      24      2  1173312000
# 530716                     1                      24      2  1173312000
#
#        Summary                                               Text  \
# 33958           I only used two maybe three tea bags and got p...
# 40548           I only used two maybe three tea bags and got p...
# 101106          I only used two maybe three tea bags and got p...
# 102979          I only used two maybe three tea bags and got p...
# 117515          I only used two maybe three tea bags and got p...
# 155712          I only used two maybe three tea bags and got p...
# 178290          I only used two maybe three tea bags and got p...
# 198474          I only used two maybe three tea bags and got p...
# 212691          I only used two maybe three tea bags and got p...
# 237565          This is a cool system only problem is that the...
# 293906          I only used two maybe three tea bags and got p...
# 299495          I only used two maybe three tea bags and got p...
# 300961          I only used two maybe three tea bags and got p...
# 333556          I only used two maybe three tea bags and got p...
# 352043          I only used two maybe three tea bags and got p...
# 357215          I only used two maybe three tea bags and got p...
# 357814          I only used two maybe three tea bags and got p...
# 360782          I only used two maybe three tea bags and got p...
# 379473          I only used two maybe three tea bags and got p...
# 380558          I only used two maybe three tea bags and got p...
# 381313          I only used two maybe three tea bags and got p...
# 386283          I only used two maybe three tea bags and got p...
# 392529          I like the product and tried it before I pucha...
# 484367          I only used two maybe three tea bags and got p...
# 486640          I only used two maybe three tea bags and got p...
# 503260          I only used two maybe three tea bags and got p...
# 530716          I only used two maybe three tea bags and got p...
#
#                                                ReviewText
# 33958    & I only used two maybe three tea bags and go...
# 40548    & I only used two maybe three tea bags and go...
# 101106   & I only used two maybe three tea bags and go...
# 102979   & I only used two maybe three tea bags and go...
# 117515   & I only used two maybe three tea bags and go...
# 155712   & I only used two maybe three tea bags and go...
# 178290   & I only used two maybe three tea bags and go...
# 198474   & I only used two maybe three tea bags and go...
# 212691   & I only used two maybe three tea bags and go...
# 237565   & This is a cool system only problem is that ...
# 293906   & I only used two maybe three tea bags and go...
# 299495   & I only used two maybe three tea bags and go...
# 300961   & I only used two maybe three tea bags and go...
# 333556   & I only used two maybe three tea bags and go...
# 352043   & I only used two maybe three tea bags and go...
# 357215   & I only used two maybe three tea bags and go...
# 357814   & I only used two maybe three tea bags and go...
# 360782   & I only used two maybe three tea bags and go...
# 379473   & I only used two maybe three tea bags and go...
# 380558   & I only used two maybe three tea bags and go...
# 381313   & I only used two maybe three tea bags and go...
# 386283   & I only used two maybe three tea bags and go...
# 392529   & I like the product and tried it before I pu...
# 484367   & I only used two maybe three tea bags and go...
# 486640   & I only used two maybe three tea bags and go...
# 503260   & I only used two maybe three tea bags and go...
# 530716   & I only used two maybe three tea bags and go...

# %% [markdown]
# ## We don't need to drop the rows where ProfileNames are missing as it is going to add barely any effect to our prediction model as it does not provide any logical inference about the sentiment of the review. Hence we shall preserve those.

# %%
df[df['ProfileName'].isnull()] #Prints all the rows where ProfileName is null(NaN)
# Out:
#             Id   ProductId          UserId ProfileName  HelpfulnessNumerator  \
# 25509    25510  B000LKZB4Y  A36BVYD0NT7Z0F         NaN                     0
# 38874    38875  B000AYDGZ2  A36BVYD0NT7Z0F         NaN                     2
# 49800    49801  B000CRHQN0  A2LYFY32LXQDON         NaN                     0
# 67077    67078  B0006348H2  A2P0P67Y55SNOX         NaN                     1
# 106550  106551  B001EQ5DG0  A1P500QXEG3IUZ         NaN                     0
# 137613  137614  B000CQE3HS   AGT3BYX5P9SLH         NaN                     0
# 163191  163192  B000CQID1A   AGT3BYX5P9SLH         NaN                     0
# 172462  172463  B001FA1L9I   AC9U70TRGPDGJ         NaN                     0
# 297275  297276  B007OXJM6E  A29D7XVSBCLFLD         NaN                     0
# 306751  306752  B000RI1W8E   AGT3BYX5P9SLH         NaN                     0
# 431598  431599  B000W5P0KI  A36BVYD0NT7Z0F         NaN                    13
# 440825  440826  B008LFAS08   AC0E8TXIYABB5         NaN                     1
# 490412  490413  B000CQE3IC   AGT3BYX5P9SLH         NaN                     0
# 491728  491729  B004772PJQ  A29D7XVSBCLFLD         NaN                     0
# 515436  515437  B004S04X4W  A2H7605OSHVIQ5         NaN                     0
# 560446  560447  B000CQID1K   AGT3BYX5P9SLH         NaN                     0
#
#         HelpfulnessDenominator  Score        Time  \
# 25509                        0      5  1314576000
# 38874                        3      1  1278374400
# 49800                        0      2  1282608000
# 67077                        1      5  1314662400
# 106550                       0      5  1326758400
# 137613                       0      5  1324684800
# 163191                       0      5  1324684800
# 172462                       0      5  1289520000
# 297275                       0      1  1325203200
# 306751                       0      5  1324684800
# 431598                      21      1  1298937600
# 440825                       1      5  1350432000
# 490412                       0      5  1324684800
# 491728                       0      1  1325203200
# 515436                       0      5  1348704000
# 560446                       0      5  1324684800
#
#                                                   Summary  \
# 25509    These are the best mints and no aspartame or BHT
# 38874   doesn't anyone care that they are putting BHT ...
# 49800   They were melted and the chocolate had turned ...
# 67077                                          Wheatgrass
# 106550                                           Finally!
# 137613                                            awesome
# 163191                                            awesome
# 172462                                          very good
# 297275                                              Burnt
# 306751                                            awesome
# 431598               WARNING:  Please read before feeding
# 440825          The perfect grinder for dog and cat food!
# 490412                                            awesome
# 491728                                              Burnt
# 515436                   Hormel Roast Beef Hash, 15-Ounce
# 560446                                            awesome
#
#                                                      Text
# 25509   I was so shocked to find out that almost all g...
# 38874   I called Kellogg's to see why Special K red be...
# 49800   We love these bars but i won't order them ship...
# 67077   Kitty seems to like this sprinkled on her food...
# 106550  You cannot find this in the stores anymore, it...
# 137613  i love them they are amazing I would eat them ...
# 163191  i love them they are amazing I would eat them ...
# 172462  came in proper packaging.  Have loved British ...
# 297275  The last SEVERAL time we bought this it tasted...
# 306751  i love them they are amazing I would eat them ...
# 431598  WARNING:  I use to feed my dogs Orijen 75% pro...
# 440825  this grinder is super easy to assemble and ope...
# 490412  i love them they are amazing I would eat them ...
# 491728  The last SEVERAL time we bought this it tasted...
# 515436  I've been buying this in the grocery stores fr...
# 560446  i love them they are amazing I would eat them ...

# %% [markdown]
# ## Now it's time for us to find duplicate entries. A duplicate review is when there are exact same reviews for multiple products (false reviews)

# %%
dup_dropped = df_treated.drop_duplicates(keep=False,subset=["Text"])
dup_dropped
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# 5            6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
# ...        ...         ...             ...                              ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                          1                       1      5  1303862400
# 1                          0                       0      1  1346976000
# 2                          1                       1      4  1219017600
# 4                          0                       0      5  1350777600
# 5                          0                       0      4  1342051200
# ...                      ...                     ...    ...         ...
# 568449                     0                       0      5  1299628800
# 568450                     0                       0      2  1331251200
# 568451                     2                       2      5  1329782400
# 568452                     1                       1      5  1331596800
# 568453                     0                       0      5  1338422400
#
#                                    Summary  \
# 0                    Good Quality Dog Food
# 1                        Not as Advertised
# 2                    "Delight" says it all
# 4                              Great taffy
# 5                               Nice Taffy
# ...                                    ...
# 568449                 Will not do without
# 568450                        disappointed
# 568451            Perfect for our maltipoo
# 568452  Favorite Training and reward treat
# 568453                         Great Honey
#
#                                                      Text  \
# 0       I have bought several of the Vitality canned d...
# 1       Product arrived labeled as Jumbo Salted Peanut...
# 2       This is a confection that has been around a fe...
# 4       Great taffy at a great price.  There was a wid...
# 5       I got a wild hair for taffy and ordered this f...
# ...                                                   ...
# 568449  Great for sesame chicken..this is a good if no...
# 568450  I'm disappointed with the flavor. The chocolat...
# 568451  These stars are small, so you can give 10-15 o...
# 568452  These are the BEST treats for training and rew...
# 568453  I am very satisfied ,product is as advertised,...
#
#                                                ReviewText
# 0       Good Quality Dog Food & I have bought several ...
# 1       Not as Advertised & Product arrived labeled as...
# 2       "Delight" says it all & This is a confection t...
# 4       Great taffy & Great taffy at a great price.  T...
# 5       Nice Taffy & I got a wild hair for taffy and o...
# ...                                                   ...
# 568449  Will not do without & Great for sesame chicken...
# 568450  disappointed & I'm disappointed with the flavo...
# 568451  Perfect for our maltipoo & These stars are sma...
# 568452  Favorite Training and reward treat & These are...
# 568453  Great Honey & I am very satisfied ,product is ...
#
# [335539 rows x 11 columns]

# %%
dup_dropped.shape
# Out:
# (335539, 11)

# %%
df_treated.shape
# Out:
# (568454, 11)

# %%
duplicaterows = df_treated[df_treated.duplicated('Text')]
duplicaterows
# Out:
#             Id   ProductId          UserId         ProfileName  \
# 29          30  B0001PB9FY  A3HDKO7OW0QNK4        Canadian Fan
# 574        575  B000G6RYNE  A3PJZ8TU8FDQ1K        Jared Castle
# 603        604  B000G6RYNE  A3PJZ8TU8FDQ1K        Jared Castle
# 1973      1974  B0017165OG  A2EPNS38TTLZYN            tedebear
# 2309      2310  B0001VWE0M   AQM74O8Z4FMS0            Sunshine
# ...        ...         ...             ...                 ...
# 568409  568410  B0018CLWM4  A2PE0AGWV6OPL7  Dark Water Mermaid
# 568410  568411  B0018CLWM4   A88HLWDCU57WG                 R28
# 568411  568412  B0018CLWM4   AUX1HSY8FX55S                 DAW
# 568412  568413  B0018CLWM4   AVZ2OZ479Q9E8        Ai Ling Chow
# 568413  568414  B0018CLWM4   AI3Y26HLPYW4L            kimosabe
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 29                         1                       1      5  1107820800
# 574                        2                       2      5  1231718400
# 603                        1                       1      5  1229385600
# 1973                       0                       0      3  1312675200
# 2309                       0                       0      2  1127606400
# ...                      ...                     ...    ...         ...
# 568409                     3                       3      5  1309651200
# 568410                     2                       2      5  1332979200
# 568411                     1                       1      5  1319500800
# 568412                     0                       0      5  1336435200
# 568413                     1                       2      2  1330041600
#
#                                             Summary  \
# 29                  The Best Hot Sauce in the World
# 574     One bite and you'll become a "chippoisseur"
# 603     One bite and you'll become a "chippoisseur"
# 1973                                      Pok Chops
# 2309                                 Below standard
# ...                                             ...
# 568409                    Quality & affordable food
# 568410                                   litter box
# 568411                                 Happy Camper
# 568412                       Two Siberians like it!
# 568413                        premium edge cat food
#
#                                                      Text  \
# 29      I don't know if it's the cactus or the tequila...
# 574     I'm addicted to salty and tangy flavors, so wh...
# 603     I'm addicted to salty and tangy flavors, so wh...
# 1973    The pork chops from Omaha Steaks were very tas...
# 2309    Too much of the white pith on this orange peel...
# ...                                                   ...
# 568409  I was very pleased with the ingredient quality...
# 568410  My main reason for the five star review has to...
# 568411  I bought this to try on two registered Maine C...
# 568412  When we brought home two 3-month-old purebred ...
# 568413  My cats don't like it. what else can I say to ...
#
#                                                ReviewText
# 29      The Best Hot Sauce in the World & I don't know...
# 574     One bite and you'll become a "chippoisseur" & ...
# 603     One bite and you'll become a "chippoisseur" & ...
# 1973    Pok Chops & The pork chops from Omaha Steaks w...
# 2309    Below standard & Too much of the white pith on...
# ...                                                   ...
# 568409  Quality & affordable food & I was very pleased...
# 568410  litter box & My main reason for the five star ...
# 568411  Happy Camper & I bought this to try on two reg...
# 568412  Two Siberians like it! & When we brought home ...
# 568413  premium edge cat food & My cats don't like it....
#
# [174875 rows x 11 columns]

# %%
num_classes = dup_dropped['Score'].nunique()
print("Number of Target Output Classes:", num_classes)
# Out:
# Number of Target Output Classes: 5

# %%
sns.countplot(dup_dropped.Score)
# Out:
# /home/anish/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Score', ylabel='count'>

# %%
sns.distplot(dup_dropped.Time)
# Out:
# /home/anish/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Time', ylabel='Density'>

# %%
dup_dropped['formattedTime'] =  pd.to_datetime(dup_dropped['Time'], unit='s')
dup_dropped['formattedTime'].dtype
# Out:
# <ipython-input-30-9243cc934ea2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dup_dropped['formattedTime'] =  pd.to_datetime(dup_dropped['Time'], unit='s')
# dtype('<M8[ns]')

# %%
dup_dropped[:5]
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# 5   6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 4                     0                       0      5  1350777600
# 5                     0                       0      4  1342051200
#
#                  Summary                                               Text  \
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 4            Great taffy  Great taffy at a great price.  There was a wid...
# 5             Nice Taffy  I got a wild hair for taffy and ordered this f...
#
#                                           ReviewText formattedTime
# 0  Good Quality Dog Food & I have bought several ...    2011-04-27
# 1  Not as Advertised & Product arrived labeled as...    2012-09-07
# 2  "Delight" says it all & This is a confection t...    2008-08-18
# 4  Great taffy & Great taffy at a great price.  T...    2012-10-21
# 5  Nice Taffy & I got a wild hair for taffy and o...    2012-07-12
